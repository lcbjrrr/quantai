# %% [markdown]
# <a href="https://colab.research.google.com/github/lcbjrrr/quantai/blob/main/Estatistica_R_6_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Regressao Linear**

# %%
nts <- read.csv('https://raw.githubusercontent.com/lcbjuk/ML/master/dados/notas%20-%20ok.csv')
head(nts)
# Out:
#   AP1  AP2  AP3  Final
# 1 10.0 10.0  9.0 9.8
# 2  9.0 10.0  9.0 9.4
# 3  9.5 10.0 10.0 9.8
# 4  9.4  9.9  9.9 9.7
# 5  9.3  9.8  9.8 9.6
# 6  9.2  9.7  9.7 9.5

# %%
reglin <- lm(nts$AP3 ~ nts$AP1 + nts$AP2)
reglin
# Out:
# Call:
# lm(formula = nts$AP3 ~ nts$AP1 + nts$AP2)
#
# Coefficients:
# (Intercept)      nts$AP1      nts$AP2
#     -0.8258      -0.3661       1.3834

# %%
prever_ap3 <- function(ap1, ap2){
  ap3 <- ap1 * -0.366 + ap2 * 1.383 - 0.825
  return(ap3)
}

print(prever_ap3(8,8))
print(prever_ap3(2,4))
print(prever_ap3(3.5,8))
# Out:
# [1] 7.311
# [1] 3.975
# [1] 8.958

# %%
plot(nts$AP2 , nts$AP3)
abline(lm(nts$AP3~nts$AP2))
# Out:
# plot without title

# %%
cor(nts)
# Out:
#       AP1         AP2       AP3         Final
# AP1   1.000000000 0.2786320 0.003717139 0.6301130
# AP2   0.278631993 1.0000000 0.952690667 0.9201748
# AP3   0.003717139 0.9526907 1.000000000 0.7763870
# Final 0.630113050 0.9201748 0.776386977 1.0000000

# %%
cor.test(nts$AP3,nts$AP2)
# Out:
# 	Pearson's product-moment correlation
#
# data:  nts$AP3 and nts$AP2
# t = 19.322, df = 38, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.9117688 0.9748822
# sample estimates:
#       cor
# 0.9526907

# %%
pairs(nts$AP3 ~ nts$AP1 + nts$AP2)
# Out:
# plot without title

# %%
install.packages('psych')
library(psych)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘mnormt’, ‘GPArotation’

# %%
pairs.panels(nts)
# Out:
# plot without title

# %%
summary(reglin)
# Out:
# Call:
# lm(formula = nts$AP3 ~ nts$AP1 + nts$AP2)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.7134 -0.2595 -0.1824  0.2717  0.7565
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.82577    0.26542  -3.111  0.00358 **
# nts$AP1     -0.36608    0.02972 -12.318 1.17e-14 ***
# nts$AP2      1.38339    0.03089  44.788  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3966 on 37 degrees of freedom
# Multiple R-squared:  0.9819,	Adjusted R-squared:  0.9809
# F-statistic:  1003 on 2 and 37 DF,  p-value: < 2.2e-16
